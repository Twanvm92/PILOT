# %%
import sys
import os
from pathlib import Path

module_path = os.path.abspath(os.path.join('..'))
if module_path not in sys.path:
    sys.path.append(module_path)

from helpers.visualization import displayCM, displayROC, get_classification_report

# %%
# confusion matrix and ROC for dataset D1 in a multi-class classification setting with C3 config
displayCM(Path('../datasets-input-neural-network/DatasetD1/'))
print(get_classification_report(root=Path('../datasets-input-neural-network/DatasetD1/')))

# confusion matrix dataset D1 in a multi-class classification setting with C3 config
displayCM(Path('../datasets-input-neural-network/DatasetD2/'))
print(get_classification_report(root=Path('../datasets-input-neural-network/DatasetD2/')))
#TODO do not have ground truth or predictions for multi-class D2 yet.
# displayROC(Path('../datasets-input-neural-network/DatasetD2/'), 5)
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00       472
#            1       1.00      1.00      1.00      2703
#            2       0.99      1.00      1.00       757
#            3       0.72      0.92      0.81        84
#            4       0.89      0.44      0.59        54
#
#     accuracy                           0.99      4070
#    macro avg       0.92      0.87      0.88      4070
# weighted avg       0.99      0.99      0.99      4070
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00     23508
#            1       1.00      1.00      1.00      2232
#
#     accuracy                           1.00     25740
#    macro avg       1.00      1.00      1.00     25740
# weighted avg       1.00      1.00      1.00     25740
